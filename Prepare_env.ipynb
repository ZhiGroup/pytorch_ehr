# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
! git clone https://github.com/ZhiGroup/pytorch_ehr.git --branch Tutorial_MIMIC
# Out:
# Cloning into 'pytorch_ehr'...
# remote: Enumerating objects: 962, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 962 (delta 56), reused 92 (delta 10), pack-reused 795
# Receiving objects: 100% (962/962), 119.00 MiB | 13.33 MiB/s, done.
# Resolving deltas: 100% (430/430), done.
# Checking out files: 100% (62/62), done.
