# %% [markdown]
# * This notebook is to demonstrate how to use Bayesian Optimization package on github <https://github.com/fmfn/BayesianOptimization> locally to tune hyperparamters for our models(LR, embedding dimension=1) for predicting heart failure onset risk on cerner sample data
# * For this demonstration, the data is the original 1 hospital (h143) previously used by retain, with 42,729 patients in total
# * The logistic regression model has the architecture of an embedding layer (embedding dimension =1), a linear activation and sigmoid transformation. The hyperparameters to be tuned are: learning rate: lr, and l2 regularization
# * To implement this, first you need to install the package: however we modify the package file a bit to bypass error and keep on iterating. The modified files could be found at Experiments/modifiedBO
# * Then **important**: you need to define a function (in our case LR_tune()) which takes in the hyperparameters: l2, lr on logscale, run the model using models, Loaddata, and TrainVaTe modules and return the best validation auc
# * Be ware that this BO package will search float parameters, so if you have int or categorical parameters you want to tune, you might want to transform those values in your function before giving those to your models
# * Then **important**: call BO function and pass your LR_tune(), a search range for each parameter ((-16, 1) means -16 and 1 inclusive), and give it points to explore (points that will give you large target values) if you want to, and call maximize() and pass number of iterations you want to run BO
# * Then you will get results of your initial designated explored points(if any), 5 initializations, and plus number of BO iterations
# * For our results: it improved our best validation auc **from manually tuned 0.76119** (l2 = np.exp(-11), lr = np.exp(-9)) to **0.78456** (l2 = np.exp(-8.4004), lr = np.exp(--6.1833))

# %%
from __future__ import print_function
from __future__ import division

import string
import re
import random

import os
import sys
import argparse
import time
import math

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F
from torchviz import make_dot, make_dot_from_trace

from sklearn.metrics import roc_auc_score  
from sklearn.metrics import roc_curve 

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

try:
    import cPickle as pickle
except:
    import pickle


from bayes_opt import BayesianOptimization

# %%
import model_lr1 as model #here the em experiment
import Loaddata as Loaddata
import TrainVaTe_lr1 as TVT

# check GPU availability
use_cuda = torch.cuda.is_available()
use_cuda
# Out:
# True

# %%
# Load data set and target values
"""
data, target = make_classification(
    n_samples=1000,
    n_features=45,
    n_informative=12,
    n_redundant=7
)
"""
set_x = pickle.load(open('Data/h143.visits', 'rb'), encoding='bytes')
set_y = pickle.load(open('Data/h143.labels', 'rb'),encoding='bytes')

model_x = []
for patient in set_x:
    model_x.append([each for visit in patient for each in visit])  
    
merged_set= [[set_y[i],model_x[i]] for i in range(len(set_y))] #list of list or list of lists of lists
print("\nLoading and preparing data...")    
train1, valid1, test1 = Loaddata.load_data(merged_set)
print("\nSample data after split:")  
print(train1[0])
print("model is", 'LR') #can change afterwards
# Out:
# Loading and preparing data...
#
# Sample data after split:
# [0, [1667, 144, 62, 85, 1667, 144, 62, 85]]
# model is LR

# %%
#function to record comprehensive searching results 
def print2file(buf, outFile):
    outfd = open(outFile, 'a')
    outfd.write(buf + '\n')
    outfd.close()

logFile='testLR_dim1.log'
header = 'model|l2|lr|BestValidAUC|TestAUC|atEpoch'
print2file(header, logFile)

# %%
#Hyperparamters to tune for LR: embed_dim, l2, lr. Define a function to return the validation AUC of the model 
def LR_tune( l2, lr):
    #little transformations to use the searched values
    #embed_dim = 2 ** int(embed_dim) #base 2 
    l2 = np.exp(l2) #base e
    lr = np.exp(lr) #base e
    ehr_model = model.EHR_LR(input_size =20000)  
    if use_cuda:
        ehr_model = ehr_model.cuda()
    optimizer = optim.Adam(ehr_model.parameters(), lr=lr, weight_decay=l2)
    #current_loss_allep=[]
    #all_losses_allep=[]
    #avg_losses_allep=[]
    #train_auc_allep =[]
    #valid_auc_allep =[]
    #test_auc_allep=[]
    
    bestValidAuc = 0.0
    bestTestAuc = 0.0
    bestValidEpoch = 0
    
    for ep in range(25):
        #start = time.time()
        current_loss, train_loss, _ = TVT.train(train1, model= ehr_model, optimizer = optimizer, batch_size = 1) #mb=args.mb
        avg_loss = np.mean(train_loss)
        #train_time = timeSince(start)
        #print ('\n Current running on: Epoch ', ep,'Training loss:',' Average loss', avg_loss)
        #print(train_loss, '\n train loss plot')
        #TVT.showPlot(train_loss)
        #eval_start = time.time()
        #train_auc, y_real, y_hat = TVT.calculate_auc(model= ehr_model, data = train1, which_model ='LR', batch_size = 1)
        #print ('\n Current running on: Epoch ', ep,' Training auc:', train_auc)
        #TVT.auc_plot(y_real, y_hat)
        valid_auc, y_real, y_hat, _  = TVT.calculate_auc(model = ehr_model, data = valid1, which_model = 'LR', batch_size = 1)
        #print ('\n Current running on: Epoch ', ep,' validation auc:', valid_auc)
        #TVT.auc_plot(y_real, y_hat)
        if valid_auc > bestValidAuc: 
            bestValidAuc = valid_auc
            bestValidEpoch = ep
            bestTestAuc, y_real, y_hat,_ = TVT.calculate_auc(model = ehr_model, data = test1, which_model = 'LR', batch_size = 1)

        if ep - bestValidEpoch >10:
            break
        
      
        buf = '|%f |%f |%d ' % (bestValidAuc, bestTestAuc, bestValidEpoch)
        pFile= 'LR'+'|'+str(l2)+'|'+str(lr)+'|'+buf    
        print2file(pFile, logFile)      
        
        #test_auc, y_real, y_hat = TVT.calculate_auc(model = ehr_model, data = test1, which_model = 'LR', batch_size = 1)
        #print ('\n Current running on: Epoch ', ep,' test auc:', test_auc)
        #TVT.auc_plot(y_real, y_hat)
        #eval_time = timeSince(eval_start)
        #print ("Epoch ", ep, "Summary:  Training_auc :", train_auc, " , Validation_auc : ", valid_auc, " ,& Test_auc : " , test_auc, " Avg Loss: ", avg_loss )
        #current_loss_allep.append(current_loss)
        #all_losses_allep.append(train_loss)
        #avg_losses_allep.append(avg_loss)
        #train_auc_allep.append(train_auc)
        #valid_auc_allep.append(valid_auc)
        #test_auc_allep.append(test_auc)
        #final_max_valid = max(valid_auc_allep)
    return bestValidAuc

# %%
if __name__ == "__main__":
    gp_params = {"alpha": 1e-4}

    LRBO = BayesianOptimization(LR_tune,
        {'l2': (-16, 1), 'lr': (-11, -2) })
    LRBO.explore({'l2': [-11], 'lr': [-9]})

    LRBO.maximize(n_iter=30, **gp_params)

    print('-' * 53)
    print('Final Results')
    print('LR: %f' % LRBO.res['max']['max_val'])
# Out:
# Initialization
# -----------------------------------------------------
#  Step |   Time |      Value |        l2 |        lr |
# Parameter containing:
# -6.4644e-01
# -7.6218e-02
#  7.4080e-01
#      ⋮
# -4.9225e-01
#  6.0644e-01
#  2.4525e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.646437                            Code
# 1 -0.076218  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.740798         b'M_BACITRACIN TOPICAL'
# 3 -0.325168    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.170204                  b'M_CEFAZOLIN'
#     1 | 21m52s |    0.76119 |  -11.0000 |   -9.0000 |
# Parameter containing:
# -0.5830
#  0.0702
# -0.7913
#    ⋮
# -1.2227
# -0.8947
# -0.2982
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.582957                            Code
# 1  0.070173  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.791270         b'M_BACITRACIN TOPICAL'
# 3 -1.034595    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -1.137885                  b'M_CEFAZOLIN'
#     2 | 20m12s |    0.75781 |   -3.8929 |   -9.1003 |
# Parameter containing:
# -5.0387e-01
#  1.1139e+00
# -7.2958e-01
#      ⋮
# -8.2668e-01
#  9.2277e-01
#  1.5908e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.503868                            Code
# 1  1.113901  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.729584         b'M_BACITRACIN TOPICAL'
# 3  0.038614    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.883002                  b'M_CEFAZOLIN'
#     3 | 11m49s |    0.65122 |   -3.4807 |   -5.3643 |
# Parameter containing:
#  2.0977e-01
#  8.8041e-01
# -4.8504e-01
#      ⋮
#  1.0080e-01
#  1.5857e+00
#  1.5055e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.209770                            Code
# 1  0.880406  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.485039         b'M_BACITRACIN TOPICAL'
# 3  0.611614    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.118595                  b'M_CEFAZOLIN'
#     4 | 19m55s |    0.74694 |  -14.5034 |   -9.7716 |
# Parameter containing:
#  1.4680e+00
# -1.5569e-01
# -2.2083e-01
#      ⋮
# -2.0739e+00
# -1.0101e+00
#  2.2920e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  1.468023                            Code
# 1 -0.155687  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.220834         b'M_BACITRACIN TOPICAL'
# 3  1.045539    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.876056                  b'M_CEFAZOLIN'
#     5 | 19m49s |    0.77217 |   -8.5288 |   -8.8767 |
# Parameter containing:
# -1.6392e+00
#  5.1968e-01
# -2.5595e-01
#      ⋮
#  3.8886e-01
# -2.4700e-01
# -2.1276e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -1.639198                            Code
# 1  0.519682  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.255954         b'M_BACITRACIN TOPICAL'
# 3 -0.817746    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.561237                  b'M_CEFAZOLIN'
#     6 | 16m49s |    0.77309 |  -11.4444 |   -7.4919 |
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |        l2 |        lr |
# Parameter containing:
#  1.1295e+00
# -1.6784e+00
# -8.7615e-01
#      ⋮
# -4.6763e-01
# -1.5243e+00
#  1.4971e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  1.129503                            Code
# 1 -1.678392  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.876154         b'M_BACITRACIN TOPICAL'
# 3  0.959895    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.035232                  b'M_CEFAZOLIN'
#     7 | 18m30s |    0.61588 |  -16.0000 |   -2.0000 |
# Parameter containing:
#  4.1254e-02
# -1.0986e-01
# -1.4607e+00
#      ⋮
# -2.2402e-01
# -1.7529e+00
# -1.7828e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.041254                            Code
# 1 -0.109864  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -1.460692         b'M_BACITRACIN TOPICAL'
# 3  1.251669    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.036075                  b'M_CEFAZOLIN'
#     8 | 08m02s |    0.53298 |    1.0000 |  -11.0000 |
# Parameter containing:
#  1.0358e+00
#  4.9419e-01
#  9.4390e-01
#      ⋮
# -1.7016e+00
#  2.6181e-01
#  3.5873e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  1.035794                            Code
# 1  0.494195  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.943895         b'M_BACITRACIN TOPICAL'
# 3  1.787314    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.216986                  b'M_CEFAZOLIN'
#     9 | 19m46s |    0.52687 |   -6.2539 |  -11.0000 |
# Parameter containing:
# -7.1041e-01
#  1.7563e-01
#  1.2579e+00
#      ⋮
# -7.5751e-01
#  3.5137e-01
#  3.8535e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.710406                            Code
# 1  0.175631  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  1.257933         b'M_BACITRACIN TOPICAL'
# 3 -1.709033    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.988351                  b'M_CEFAZOLIN'
#    10 | 16m38s |    0.55679 |    1.0000 |   -2.0000 |
# Parameter containing:
# -9.0664e-01
#  8.3376e-01
# -6.5362e-01
#      ⋮
#  1.1866e+00
#  6.4766e-01
#  1.0131e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.906644                            Code
# 1  0.833762  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.653615         b'M_BACITRACIN TOPICAL'
# 3 -1.757988    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.357691                  b'M_CEFAZOLIN'
#    11 | 12m24s |    0.63476 |   -9.4844 |   -2.0000 |
# Parameter containing:
# -2.8030e-01
# -6.5813e-01
#  1.0771e+00
#      ⋮
#  2.9838e-01
# -1.2135e-01
#  6.0389e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.280301                            Code
# 1 -0.658135  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  1.077123         b'M_BACITRACIN TOPICAL'
# 3 -0.397298    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.780231                  b'M_CEFAZOLIN'
#    12 | 11m14s |    0.52011 |    1.0000 |   -6.8044 |
# Parameter containing:
#  1.0434e+00
# -6.1438e-01
# -1.0184e-01
#      ⋮
#  9.6183e-01
# -7.4806e-01
#  4.0179e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  1.043413                            Code
# 1 -0.614383  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.101845         b'M_BACITRACIN TOPICAL'
# 3 -0.239252    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -1.071589                  b'M_CEFAZOLIN'
#    13 | 09m36s |    0.76861 |  -16.0000 |   -6.7762 |
# Parameter containing:
#  3.2290e-01
# -7.0989e-01
#  7.1377e-01
#      ⋮
#  1.1134e+00
# -5.0351e-01
# -1.7239e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.322902                            Code
# 1 -0.709894  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.713774         b'M_BACITRACIN TOPICAL'
# 3 -1.221734    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.172068                  b'M_CEFAZOLIN'
#    14 | 26m04s |    0.52027 |  -16.0000 |  -11.0000 |
# Parameter containing:
# -5.0675e-01
# -4.3547e-01
#  8.5351e-01
#      ⋮
# -1.1839e-01
# -2.9503e-01
# -1.7792e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.506749                            Code
# 1 -0.435465  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.853513         b'M_BACITRACIN TOPICAL'
# 3 -0.026075    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.004362                  b'M_CEFAZOLIN'
#    15 | 28m11s |    0.78217 |   -7.1882 |   -6.3016 |
# Parameter containing:
# -2.6690e-01
#  2.9695e-01
#  4.9044e-02
#      ⋮
# -1.8664e+00
# -1.1696e-01
# -1.8932e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.266904                            Code
# 1  0.296954  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.049044         b'M_BACITRACIN TOPICAL'
# 3  1.643607    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.213510                  b'M_CEFAZOLIN'
#    16 | 12m43s |    0.75503 |  -13.8584 |   -5.0264 |
# Parameter containing:
# -3.8109e-01
# -3.3693e-01
#  8.1388e-01
#      ⋮
#  2.6405e-01
#  3.8027e-01
#  7.4077e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.381089                            Code
# 1 -0.336932  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.813880         b'M_BACITRACIN TOPICAL'
# 3 -1.679101    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.490831                  b'M_CEFAZOLIN'
#    17 | 25m02s |    0.76308 |  -14.0229 |   -7.6896 |
# Parameter containing:
# -1.5167e-01
#  4.4071e-01
# -1.9550e+00
#      ⋮
# -7.1001e-01
# -9.8930e-01
# -1.7379e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.151665                            Code
# 1  0.440711  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -1.955047         b'M_BACITRACIN TOPICAL'
# 3 -0.600602    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.537198                  b'M_CEFAZOLIN'
#    18 | 25m04s |    0.78002 |   -5.7732 |   -7.7989 |
# Parameter containing:
# -2.4210e-01
#  5.3678e-01
# -1.4415e-01
#      ⋮
# -7.8548e-01
# -4.8847e-01
# -1.4422e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.242096                            Code
# 1  0.536776  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.144147         b'M_BACITRACIN TOPICAL'
# 3  1.113546    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -1.519608                  b'M_CEFAZOLIN'
#    19 | 18m17s |    0.78304 |   -9.5729 |   -5.9139 |
# Parameter containing:
# -4.4124e-01
#  1.9576e+00
#  6.9730e-01
#      ⋮
#  1.4622e+00
# -1.3933e-01
#  2.0604e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.441244                            Code
# 1  1.957557  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.697300         b'M_BACITRACIN TOPICAL'
# 3  0.449103    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.683118                  b'M_CEFAZOLIN'
#    20 | 19m18s |    0.77688 |   -8.6657 |   -7.3705 |
# /home/jzhu8/.local/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.65402039e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 50, 'nit': 3, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# Parameter containing:
# -7.6477e-01
#  2.5619e-02
#  1.4927e+00
#      ⋮
# -7.7463e-01
#  7.6500e-01
# -1.6530e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.764771                            Code
# 1  0.025619  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  1.492747         b'M_BACITRACIN TOPICAL'
# 3  1.932553    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.223412                  b'M_CEFAZOLIN'
#    21 | 12m22s |    0.53702 |   -5.0580 |   -2.0000 |
# Parameter containing:
# -1.2783e+00
# -1.2361e+00
#  2.4593e-01
#      ⋮
# -1.1686e+00
# -2.6337e-01
# -1.1037e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -1.278262                            Code
# 1 -1.236094  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.245931         b'M_BACITRACIN TOPICAL'
# 3  0.529936    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  1.375595                  b'M_CEFAZOLIN'
#    22 | 11m27s |    0.75288 |  -16.0000 |   -4.9168 |
# Parameter containing:
# -4.3772e-01
# -2.8627e+00
# -5.2456e-01
#      ⋮
# -8.1294e-01
#  1.3489e+00
# -4.5187e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.437722                            Code
# 1 -2.862699  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.524563         b'M_BACITRACIN TOPICAL'
# 3  2.168889    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.656952                  b'M_CEFAZOLIN'
#    23 | 19m58s |    0.77529 |  -11.2172 |   -4.6968 |
# Parameter containing:
#  0.1923
# -1.0796
#  0.7075
#    ⋮
# -0.7212
#  0.6403
#  3.6640
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.192284                            Code
# 1 -1.079618  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.707511         b'M_BACITRACIN TOPICAL'
# 3  0.288452    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -2.307478                  b'M_CEFAZOLIN'
#    24 | 13m06s |    0.66459 |   -2.3803 |   -8.4120 |
# Parameter containing:
#  3.2272e-01
#  1.6997e+00
# -2.2291e-01
#      ⋮
# -1.7723e-01
# -5.9351e-01
# -5.4134e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.322725                            Code
# 1  1.699722  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.222914         b'M_BACITRACIN TOPICAL'
# 3  1.444222    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.010768                  b'M_CEFAZOLIN'
#    25 | 18m19s |    0.76978 |   -8.5449 |   -4.6562 |
# Parameter containing:
#  7.9630e-01
# -4.1216e-01
#  1.3336e+00
#      ⋮
# -5.1700e-01
# -3.6539e-01
#  8.3178e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.796299                            Code
# 1 -0.412156  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  1.333628         b'M_BACITRACIN TOPICAL'
# 3 -0.278984    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.050328                  b'M_CEFAZOLIN'
#    26 | 18m38s |    0.70219 |  -12.5637 |  -10.4022 |
# /home/jzhu8/.local/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.54075366e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 46, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# Parameter containing:
#  1.5299e+00
# -1.7964e-02
#  1.0447e-01
#      ⋮
# -7.1884e-01
# -1.6650e+00
# -8.4150e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  1.529939                            Code
# 1 -0.017964  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.104468         b'M_BACITRACIN TOPICAL'
# 3  0.172383    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  1.079036                  b'M_CEFAZOLIN'
#    27 | 13m59s |    0.77841 |   -7.1544 |   -7.8085 |
# Parameter containing:
# -1.9835e-02
#  1.0592e+00
# -2.2739e+00
#      ⋮
# -8.4625e-01
#  1.1436e+00
#  1.7440e-03
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.019835                            Code
# 1  1.059249  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -2.273923         b'M_BACITRACIN TOPICAL'
# 3 -0.119679    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.752667                  b'M_CEFAZOLIN'
#    28 | 14m57s |    0.77133 |   -4.8923 |   -7.7471 |
# Parameter containing:
#  1.5201e+00
#  9.1182e-01
# -4.5721e-01
#      ⋮
# -9.1156e-02
# -5.3234e-01
# -1.3369e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  1.520140                            Code
# 1  0.911820  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.457214         b'M_BACITRACIN TOPICAL'
# 3  0.582723    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  1.730525                  b'M_CEFAZOLIN'
#    29 | 20m06s |    0.77289 |   -9.7790 |   -7.7029 |
# Parameter containing:
#  1.6303e-02
#  4.8909e-01
# -1.4156e+00
#      ⋮
# -5.4418e-01
#  1.9151e-01
# -1.1818e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.016303                            Code
# 1  0.489090  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -1.415578         b'M_BACITRACIN TOPICAL'
# 3  0.818741    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.520846                  b'M_CEFAZOLIN'
#    30 | 18m41s |    0.76289 |  -13.0395 |   -8.7109 |
# Parameter containing:
# -0.5142
# -0.2842
#  0.0168
#    ⋮
#  0.5251
#  0.5801
# -0.9311
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.514180                            Code
# 1 -0.284152  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.016751         b'M_BACITRACIN TOPICAL'
# 3  0.918384    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.682268                  b'M_CEFAZOLIN'
#    31 | 18m08s |    0.77796 |  -11.1283 |   -5.8797 |
# Parameter containing:
# -0.2070
# -1.8846
#  0.4688
#    ⋮
#  0.4889
#  0.9981
# -0.1536
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0 -0.207007                            Code
# 1 -1.884591  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.468785         b'M_BACITRACIN TOPICAL'
# 3  1.022794    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.578699                  b'M_CEFAZOLIN'
#    32 | 18m00s |    0.78443 |   -9.9218 |   -5.0088 |
# Parameter containing:
#  3.1799e-01
#  7.7802e-02
# -1.7037e+00
#      ⋮
# -2.4759e-01
# -4.8575e-02
#  4.1231e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.317988                            Code
# 1  0.077802  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -1.703669         b'M_BACITRACIN TOPICAL'
# 3  0.563182    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -0.204675                  b'M_CEFAZOLIN'
#    33 | 16m33s |    0.78456 |   -8.4004 |   -6.1833 |
# Parameter containing:
#  1.3683
#  0.3567
#  1.5032
#    ⋮
# -1.4033
#  0.3359
#  0.0632
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  1.368251                            Code
# 1  0.356690  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  1.503215         b'M_BACITRACIN TOPICAL'
# 3 -1.154523    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.347975                  b'M_CEFAZOLIN'
#    34 | 19m44s |    0.78413 |   -6.2935 |   -6.6428 |
# Parameter containing:
#  4.9314e-01
# -1.2157e+00
# -6.2221e-01
#      ⋮
#  4.4133e-01
#  5.0169e-02
# -1.5636e+00
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.493137                            Code
# 1 -1.215746  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2 -0.622210         b'M_BACITRACIN TOPICAL'
# 3 -1.386388    b'M_BUPIVACAINE-EPINEPHRINE'
# 4 -1.318739                  b'M_CEFAZOLIN'
#    35 | 11m30s |    0.77829 |   -7.4420 |   -7.2186 |
# Parameter containing:
#  2.8926e-01
# -1.7630e-01
#  8.8700e-01
#      ⋮
#  4.8261e-01
#  7.2823e-01
#  6.3648e-01
# [torch.FloatTensor of size 20000x1]
#
#         emb                           types
# 0  0.289257                            Code
# 1 -0.176305  b'M_ACETAMINOPHEN-HYDROCODONE'
# 2  0.886998         b'M_BACITRACIN TOPICAL'
# 3 -0.408339    b'M_BUPIVACAINE-EPINEPHRINE'
# 4  0.035471                  b'M_CEFAZOLIN'
#    36 | 19m24s |    0.76166 |  -15.3421 |   -8.1395 |
# -----------------------------------------------------
# Final Results
# LR: 0.784561

# %%
np.exp(-8.4004)
# Out:
# 0.00022477739523616444

# %%
np.exp(-6.1833)
# Out:
# 0.002063606703809012
